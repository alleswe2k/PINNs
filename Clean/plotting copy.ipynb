# %%
import matplotlib.pyplot as plt
import json
import numpy as np
import pandas as pd

# %%
file_name = "optimization.json"

with open(file_name, "r") as f:
    data = json.load(f)

# %%
print(data.keys())
# Out:
# dict_keys(['adam', 'lbfgs', 'both'])

# %%
adam = data['adam']
lbfgs = data['lbfgs']
both = data['both']

color = ['Blue', 'Orange', 'Green']

# %%
print(both[-1])
# Out:
# 0.0002266088267788291

# %%
plt.semilogy(adam, label="Adam", color=color[0])
plt.semilogy(lbfgs, label="L-BFGS", color=color[1])
plt.semilogy(both, label="Combining both", color=color[2])


plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Comparing optimization algorithms")
plt.grid()

# %%
from matplotlib import rcParams

rcParams.update({
    'font.size': 14,
    'axes.titlesize': 14,
    'axes.labelsize': 14,
    'xtick.labelsize': 14,
    'ytick.labelsize': 14,
})

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(12, 5))

ax1.semilogy(adam, color="blue")
ax1.grid(True)
ax1.set_title("Adam")
ax1.set_xlabel("Epochs")

ax2.semilogy(lbfgs, color="red")
ax2.grid(True)
ax2.set_title("L-BFGS")
ax2.set_xlabel("Epochs")


ax3.semilogy(both, color="green")
ax3.grid(True)
ax3.set_title("Combining both")
ax3.set_xlabel("Epochs")

plt.tight_layout()
plt.show()
