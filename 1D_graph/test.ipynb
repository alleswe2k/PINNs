# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
d = 0.2
H = 1

k_g = 0.284 + 2 / (1-d/H) - 0.6*(1-d/H) + 1.32*(1-d/H)**2

k_n = 2 + 0.284*(1-d/H) - 0.6*(1-d/H)**2 + 1.32*(1-d/H)**3
print(k_g)
print(k_n)
# Out:
# 3.1488
# 2.51904
