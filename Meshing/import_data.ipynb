# %%
import pandas as pd

# %%
csv_file = "ansys_data/hole_middle_r01.csv"
df = pd.read_csv(csv_file, sep=",", skipinitialspace=True)
print(df.head)
# Out:
# <bound method NDFrame.head of       Node ID  Equivalent Stress      Stress X      Stress Y  Deformation X  \
# 0           1       6.545445e+07  6.762082e+07  1.490652e+07       0.000000
# 1           2       4.999980e+07  4.999977e+07 -5.742162e+01       0.001484
# 2           3       4.999874e+07  4.999739e+07 -2.699443e+03       0.001484
# 3           4       6.541888e+07  6.761831e+07  1.484614e+07       0.000000
# 4           5       5.418784e+07 -7.747619e+05 -5.456977e+07       0.000964
# ...       ...                ...           ...           ...            ...
# 5524     5525       4.546138e+07 -1.583121e+06 -4.606689e+07       0.000512
# 5525     5526       6.322110e+07  5.301161e+07 -8.772232e+06       0.000590
# 5526     5527       7.949563e+07  8.054003e+07  7.272670e+06       0.000653
# 5527     5528       3.192433e+07  3.124291e+07  3.873429e+05       0.000484
# 5528     5529       3.872634e+07  2.710636e+07 -6.527680e+06       0.000520
#
# ...

# %%
a = [1, 2, 3, 4 , 5]

print(a)
print(a[:3])
# Out:
# [1, 2, 3, 4, 5]
# [1, 2, 3]
